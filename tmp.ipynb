# %%
import requests

# %%
API_KEY = "w550703c91eb26504ed1b6f176f9e52e9d"
API_SECRET = "3c02f020c69afae8890f402bf6440483"

# %%
URL = 'https://wykop.pl/api/v3'

# %%
AUTH_JSON = {
    "data": {
        "key": API_KEY,
        "secret": API_SECRET
    }
    }

# %%
auth_data = requests.post(f"{URL}/auth", json=AUTH_JSON).json()

# %%
headers = {'Authorization': f"Bearer {auth_data['data']['token']}"}

# %%
requests.get(f"{URL}/profile/users/iforgotmypass_/entries/added", headers=headers, params={"limit": 1000}).json()
# Out:
# {'data': [{'id': 76434471,
#    'slug': 'ale-to-jest-bangier-muzyka-house-channeltres',
#    'author': {'username': 'iforgotmypass_',
#     'gender': 'f',
#     'company': False,
#     'avatar': 'https://wykop.pl/cdn/c3397992/iforgotmypass__LTPAoXFdqF.jpg',
#     'status': 'active',
#     'color': 'orange',
#     'verified': False,
#     'rank': {'position': None, 'trend': 0},
#     'blacklist': False,
#     'follow': False,
#     'note': False,
#     'online': False},
#    'device': '',
#    'created_at': '2024-05-26 00:55:55',
#    'voted': 0,
#    'content': 'ale to jest bangier\n#muzyka #house #channeltres',
#    'media': {'photo': None,
#     'embed': {'key': 'xRQ1D37lOaMPgwX49B5n0jMQWqvejqreWAY6d2kmENyVLJZbz8',
#      'type': 'youtube',
#      'thumbnail': 'https://wykop.pl/cdn/c3201142/ca0f3823bd19616c2681d7ff21cca8bcae1b674f8e3aea99a8bbc84a8beaa582.jpg?author=iforgotmypass_&auth=dbc3236a68f3e16871964a3770def1d0',
#      'url': 'https://www.youtube.com/watch?v=8pReEUxHxJM',
# ...
